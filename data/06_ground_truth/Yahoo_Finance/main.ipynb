# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime


ticker = "KC=F" #mã arabica


data = yf.download(ticker, period="3y", interval="1d")

data.columns = data.columns.droplevel(1)

data = data.reset_index()

data["Gia_vnd"]=data["Close"]/100*2.20462*26293.92
current_date = datetime.now().strftime("%Y-%m-%d")
filename = f"coffee_arabica_yahoo{current_date}.csv"



print(data.head())




data.to_csv(filename)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Date       Close        High         Low        Open  Volume  \
# 0     2023-03-15  178.050003  177.250000  177.250000  177.250000       2
# 1     2023-03-16  185.500000  185.500000  185.500000  185.500000       0
# 2     2023-03-17  183.000000  182.250000  181.649994  181.649994      66
# 3     2023-03-20  184.899994  184.899994  184.899994  184.899994       1
# 4     2023-03-21  186.699997  186.699997  186.699997  186.699997   13969
#
# Price        Gia_vnd
# 0      103212.207221
# 1      107530.829044
# 2      106081.626496
# 3      107183.016894
# 4      108226.444498
